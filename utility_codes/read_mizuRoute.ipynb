# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import glob

import hydrant.topology.mizuRoute as mz


file_name  = '/home/shg096/projects/def-mclark/shg096/mizuRoute_paper/case_1_HDMA_HydroLakes/output/HDMA_ERA5/HDMA_ERA5_no_lake.h.197*-01-01-00000.nc'

# IDs
order_ids = [3044060] #, 3044061, 3044062]  # Modify or extend this list with desired IDs

ds = mz.reorder_files (file_name,
                       order_ids = order_ids,
                       var_id = 'reachID',
                       dim_id = 'seg',
                       var_time = 'time',
                       dim_time = 'time',
                       var_to_keep = ['IRFroutedRunoff','volume'])
# Out:
# The number of files passed to function is larger than 1. The function output will be set to None. The reorder files are going to be set written in reorder folder with prefix of reorder_
# /home/shg096/projects/def-mclark/shg096/mizuRoute_paper/case_1_HDMA_HydroLakes/output/HDMA_ERA5/HDMA_ERA5_no_lake.h.1970-01-01-00000.nc
# ['basinID', 'basRunoff']
# /home/shg096/projects/def-mclark/shg096/mizuRoute_paper/case_1_HDMA_HydroLakes/output/HDMA_ERA5/HDMA_ERA5_no_lake.h.1971-01-01-00000.nc
# ['basinID', 'basRunoff']
# /home/shg096/projects/def-mclark/shg096/mizuRoute_paper/case_1_HDMA_HydroLakes/output/HDMA_ERA5/HDMA_ERA5_no_lake.h.1972-01-01-00000.nc
# ['basinID', 'basRunoff']
# /home/shg096/projects/def-mclark/shg096/mizuRoute_paper/case_1_HDMA_HydroLakes/output/HDMA_ERA5/HDMA_ERA5_no_lake.h.1973-01-01-00000.nc
# ['basinID', 'basRunoff']
# /home/shg096/projects/def-mclark/shg096/mizuRoute_paper/case_1_HDMA_HydroLakes/output/HDMA_ERA5/HDMA_ERA5_no_lake.h.1974-01-01-00000.nc
# ...

# %%
import xarray as xr
# ds = xr.open_dataset('/home/shg096/projects/def-mclark/shg096/mizuRoute_paper/case_1_HDMA_HydroLakes/output/HDMA_ERA5/HDMA_ERA5_no_lake.h.1970-01-01-00000.nc')
ds = xr.open_dataset('./reorder/reorder_HDMA_ERA5_no_lake.h.1971-01-01-00000.nc')
ds.close()
# Out:
# array([ 123.766045,  123.312164,  122.736404,  122.06695 ,  121.382095,
#         120.74812 ,  120.18172 ,  119.662315,  119.17386 ,  118.74915 ,
#         118.49776 ,  118.58182 ,  119.1221  ,  120.08092 ,  121.207085,
#         122.1017  ,  122.388084,  121.88477 ,  120.74273 ,  119.34087 ,
#         118.048   ,  117.15706 ,  116.93575 ,  117.75582 ,  120.127884,
#         124.48321 ,  130.72699 ,  137.7943  ,  143.68571 ,  146.28468 ,
#         144.53534 ,  139.06519 ,  131.7806  ,  124.79723 ,  119.481575,
#         116.14972 ,  114.375435,  113.507866,  113.036194,  112.6813  ,
#         112.30009 ,  111.77651 ,  111.017075,  110.01795 ,  108.93396 ,
#         108.17665 ,  108.182175,  109.17259 ,  111.3251  ,  114.77603 ,
#         119.400024,  124.58765 ,  129.24219 ,  132.1262  ,  132.40071 ,
#         130.02393 ,  125.716   ,  120.587006,  115.714615,  111.83203 ,
#         109.17093 ,  107.51037 ,  106.42327 ,  105.53877 ,  104.66874 ,
# ...
